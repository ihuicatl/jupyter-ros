# %% [markdown]
# # Work in Progress

# %% [markdown]
# ### Gazebo Extension
# ![08_gazExBoxes.png](attachment:60e32531-692f-4024-84cf-2bf39836054e.png)

# %% [markdown]
# ### URDF Extension
# ![demo_urdf (2).png](attachment:72356181-349b-498f-9977-d035cbab45c0.png)

# %% [markdown]
# ### ROS2
# ![image.png](attachment:b465a1a0-a1aa-4cd9-b5da-1649abe19b2c.png)

# %% [markdown]
# ### JROS Profile
# ![jros2.png](attachment:35c28138-ab6f-46ad-81b5-864ee3166dd5.png)

# %% [markdown]
# # ACDC
